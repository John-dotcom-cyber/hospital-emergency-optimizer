# %%
import pandas as pd
import matplotlib.pyplot as plt

# TODO: charger un fichier d'exemple dans data/examples/
# df = pd.read_csv("data/examples/urgences_exemple.csv")

# df["datetime"] = pd.to_datetime(df["datetime"])
# df.set_index("datetime")["arrivals"].plot(figsize=(12, 4))
# plt.title("Flux d'arrivées aux urgences (exemple)")
# plt.show()
