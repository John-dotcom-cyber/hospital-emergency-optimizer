# %%
from src.simulation.mm1 import mm1_simulation
import numpy as np

wait_times = mm1_simulation(arrival_rate=0.8, service_rate=1.0, n_customers=500)
print("Temps d'attente moyen :", np.mean(wait_times))
